# %%
#Challenge 1: Get a Picture

import requests
import json   # a list of dictionaries
from pandas.io.json import json_normalize

response = requests.get('https://xkcd.com/')
response
# Out:
# <Response [200]>

# %%
type(response)
# Out:
# requests.models.Response

# %%
response.status_code
# Out:
# 200

# %%
response.headers
# Out:
# {'Connection': 'keep-alive', 'Content-Length': '2920', 'Server': 'nginx', 'Content-Type': 'text/html; charset=UTF-8', 'Last-Modified': 'Fri, 14 Apr 2023 13:46:07 GMT', 'ETag': 'W/"6439591f-1d1b"', 'Expires': 'Fri, 14 Apr 2023 13:52:25 GMT', 'Cache-Control': 'max-age=300', 'Content-Encoding': 'gzip', 'Via': '1.1 varnish, 1.1 varnish', 'Accept-Ranges': 'bytes', 'Date': 'Mon, 17 Apr 2023 13:24:25 GMT', 'Age': '188', 'X-Served-By': 'cache-dfw-kdfw8210096-DFW, cache-mrs10546-MRS', 'X-Cache': 'HIT, HIT', 'X-Cache-Hits': '8411, 1', 'X-Timer': 'S1681737866.789733,VS0,VE3', 'Vary': 'Accept-Encoding'}

# %%
response.headers['Expires']
# Out:
# 'Fri, 14 Apr 2023 13:52:25 GMT'

# %%
response.url
# Out:
# 'https://xkcd.com/'

# %%
x = response.content
x
# Out:
# b'<!DOCTYPE html>\n<html>\n<head>\n<link rel="stylesheet" type="text/css" href="/s/7d94e0.css" title="Default"/>\n<title>xkcd: Linguistics Gossip</title>\n<meta http-equiv="X-UA-Compatible" content="IE=edge"/>\n<link rel="shortcut icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="icon" href="/s/919f27.ico" type="image/x-icon"/>\n<link rel="alternate" type="application/atom+xml" title="Atom 1.0" href="/atom.xml"/>\n<link rel="alternate" type="application/rss+xml" title="RSS 2.0" href="/rss.xml"/>\n<!-- <script type="text/javascript" src="/s/b66ed7.js" async></script>\n<script type="text/javascript" src="/s/1b9456.js" async></script> -->\n\n<meta property="og:site_name" content="xkcd">\n\n<meta property="og:title" content="Linguistics Gossip">\n<meta property="og:url" content="https://xkcd.com/2763/">\n<meta property="og:image" content="https://imgs.xkcd.com/comics/linguistics_gossip_2x.png">\n<meta name="twitter:card" content="summary_large_image">\n\n</head>\n<body>\n<div 
# ...

# %%
pip install ipython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install ipython
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import requests
import re
import IPython

image_path = requests.get("https://imgs.xkcd.com/comics/grownups.png")

IPython.display.Image(image_path, width=260)

with open(r'grownups.png', 'wb') as f:
    f.write(image_path.content)

# %%
# Challenge 2: Get a password

import requests
import json   # a list of dictionaries
from pandas.io.json import json_normalize

response2 = requests.get('https://httpbin.org/get')
response2
# Out:
# <Response [200]>

# %%
response2.content
# Out:
# b'{\n  "args": {}, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.28.1", \n    "X-Amzn-Trace-Id": "Root=1-643d61b2-6d5e564d5f5f0c3328788c4c"\n  }, \n  "origin": "185.146.221.98", \n  "url": "https://httpbin.org/get"\n}\n'

# %%
para = {'things':2,'total':25}

response2 = requests.get('https://httpbin.org/get', params = para)

response2.url
# Out:
# 'https://httpbin.org/get?things=2&total=25'

# %%
response2.content
# Out:
# b'{\n  "args": {\n    "things": "2", \n    "total": "25"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.28.1", \n    "X-Amzn-Trace-Id": "Root=1-643d637a-32a8f4a86d70a10a7551d73f"\n  }, \n  "origin": "185.146.221.98", \n  "url": "https://httpbin.org/get?things=2&total=25"\n}\n'

# %%
para2 = {'username': 'huyen', 'password': 234}

response2 = requests.get('https://httpbin.org/get', params = para2)

response2.content
# Out:
# b'{\n  "args": {\n    "password": "234", \n    "username": "huyen"\n  }, \n  "headers": {\n    "Accept": "*/*", \n    "Accept-Encoding": "gzip, deflate, br", \n    "Host": "httpbin.org", \n    "User-Agent": "python-requests/2.28.1", \n    "X-Amzn-Trace-Id": "Root=1-643d65d6-7602b776016d37716e36a826"\n  }, \n  "origin": "185.146.221.98", \n  "url": "https://httpbin.org/get?username=huyen&password=234"\n}\n'

# %%
x = response2.json()
x
# Out:
# {'args': {'password': '234', 'username': 'huyen'},
#  'headers': {'Accept': '*/*',
#   'Accept-Encoding': 'gzip, deflate, br',
#   'Host': 'httpbin.org',
#   'User-Agent': 'python-requests/2.28.1',
#   'X-Amzn-Trace-Id': 'Root=1-643d65d6-7602b776016d37716e36a826'},
#  'origin': '185.146.221.98',
#  'url': 'https://httpbin.org/get?username=huyen&password=234'}

# %%
x.get('args')
# Out:
# {'password': '234', 'username': 'huyen'}

# %%
# challenge 3: Hidden Cold Joke

response3 = requests.get('https://github.com/ironhack-datalabs/scavenger')
response3
# Out:
# <Response [200]>

# %%
response3.content
# Out:
# b'\n\n\n\n\n\n\n<!DOCTYPE html>\n<html lang="en" data-color-mode="auto" data-light-theme="light" data-dark-theme="dark" data-a11y-animated-images="system">\n  <head>\n    <meta charset="utf-8">\n  <link rel="dns-prefetch" href="https://github.githubassets.com">\n  <link rel="dns-prefetch" href="https://avatars.githubusercontent.com">\n  <link rel="dns-prefetch" href="https://github-cloud.s3.amazonaws.com">\n  <link rel="dns-prefetch" href="https://user-images.githubusercontent.com/">\n  <link rel="preconnect" href="https://github.githubassets.com" crossorigin>\n  <link rel="preconnect" href="https://avatars.githubusercontent.com">\n\n  <link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/light-0946cdc16f15.css" /><link crossorigin="anonymous" media="all" rel="stylesheet" href="https://github.githubassets.com/assets/dark-3946c959759a.css" /><link data-color-theme="dark_dimmed" crossorigin="anonymous" media="all" rel="stylesheet" data-
# ...
